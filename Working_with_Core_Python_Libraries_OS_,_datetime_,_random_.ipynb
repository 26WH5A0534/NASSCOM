# %% [markdown]
# <a href="https://colab.research.google.com/github/26WH5A0534/NASSCOM/blob/main/Working_with_Core_Python_Libraries_OS_%2C_datetime_%2C_random_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. os – Operating System Interface

# %%
import os


print("Current Directory:", os.getcwd())


print("Files and Folders:", os.listdir())


os.mkdir("demo_folder")


os.rename("demo_folder", "renamed_folder")

os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %% [markdown]
# 2. datetime – Date and Time Handling

# %%
from datetime import datetime, date, timedelta

now = datetime.now()
print("Now:", now)


today = date.today()
print("Today's Date:", today)


dob = date(2000, 1, 1)
print("DOB:", dob)


yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)


formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-07-30 09:08:35.702483
# Today's Date: 2026-07-30
# DOB: 2000-01-01
# Yesterday: 2026-07-29
# Tomorrow: 2026-07-31
# Formatted DateTime: 30-07-2026 09:08:35

# %% [markdown]
# 3. random – Random Numbers & Choices

# %%
import random


print("Random Int:", random.randint(1, 100))

print("Random Float:", random.random())


colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))


random.shuffle(colors)
print("Shuffled List:", colors)


print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 95
# Random Float: 0.9573731864348274
# Random Color: blue
# Shuffled List: ['red', 'blue', 'green']
# Sample: [35, 7, 38, 16, 19]

# %% [markdown]
# 4. collections – Specialized Containers

# %% [markdown]
# A. Counter

# %%
from collections import Counter

fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %% [markdown]
# B. defaultdict

# %%
from collections import defaultdict

marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("English Marks (not set):", marks['English'])
# Out:
# English Marks (not set): 0

# %% [markdown]
# C. namedtuple

# %%
from collections import namedtuple

Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %% [markdown]
# D. deque

# %%
from collections import deque

# Double-ended queue
dq = deque([1, 2, 3])
dq.append(4)        # Add to right
dq.appendleft(0)    # Add to left
dq.pop()            # Remove from right
dq.popleft()        # Remove from left
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])
